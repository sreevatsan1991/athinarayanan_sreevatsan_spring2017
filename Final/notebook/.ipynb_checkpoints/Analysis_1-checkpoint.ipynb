# %%
import pandas as pd

# %%
df1=pd.read_csv("Other Files\YelpData.csv")

# %%
df2=pd.read_csv("Other Files\\ZomatoData.csv")

# %%
new_df = pd.merge(df1, df2,  how='inner', left_on=['name','zip_code'], right_on = ['name','zip_code'])

# %%
new_df.to_csv("joineddata.csv")

# %%
new_df['Price Rating Yelp']=new_df['price'].str.len()

# %%
new_df.columns
# Out:
# Index(['id_x', 'name', 'review_count', 'price', 'is_closed', 'latitude_x',
#        'longitude_x', 'city_x', 'state', 'zip_code', 'country_x', 'rating',
#        'phone', 'term', 'image_x', 'id_y', 'city_y', 'country_y', 'latitude_y',
#        'longitude_y', 'price_range', 'rest_rating', 'rating_text', 'votes',
#        'image_y', 'Price Rating Yelp'],
#       dtype='object')

# %%
df=new_df.groupby(['city_x'])['rating','rest_rating'].mean().reset_index()

# %%
# %matplotlib inline
import seaborn
# Create the general blog and the "subplots" i.e. the bars
f, ax1 = plt.subplots(1, figsize=(10,5))

# Set the bar width
bar_width = 0.75

# positions of the left bar-boundaries
bar_l = [i+1 for i in range(len(df['rating']))]

# positions of the x-axis ticks (center of the bars as bar labels)
tick_pos = [i+(bar_width/2) for i in bar_l]

# Create a bar plot, in position bar_1
ax1.bar(bar_l,
        # using the pre_score data
        df['rating'],
        # set the width
        width=bar_width,
        # with the label pre score
        label='Rating',
        # with alpha 0.5
        alpha=0.5,
        # with color
        color='#F4561D')

# Create a bar plot, in position bar_1
ax1.bar(bar_l,
        # using the mid_score data
        df['rest_rating'],
        # set the width
        width=bar_width,
        # with pre_score on the bottom
        bottom=df['rating'],
        # with the label mid score
        label='Ress',
        # with alpha 0.5
        alpha=0.5,
        # with color
        color='#F1911E')

# Create a bar plot, in position bar_1


# set the x ticks with names
plt.xticks(tick_pos, df['city_x'])

# Set the label and legends
ax1.set_ylabel("Total Score")
ax1.set_xlabel("Test Subject")
plt.legend(loc='upper left')

# Set a buffer around the edge
plt.xlim([min(tick_pos)-bar_width, max(tick_pos)+bar_width])
# Out:
# (0.625, 18.125)

# %%
new_df.groupby(['city_x'])['Price Rating Yelp','price_range'].mean().reset_index()
# Out:
#          city_x  Price Rating Yelp  price_range
# 0       Atlanta           2.056180     2.528090
# 1      Auckland           2.028571     3.257143
# 2        Austin           2.022989     2.137931
# 3        Boston           2.194444     3.000000
# 4       Chicago           2.023256     2.709302
# 5       Houston           2.000000     2.734694
# 6   Los Angeles           2.088889     2.088889
# 7        Lowell           1.629630     1.666667
# 8     Melbourne           2.150000     3.350000
# 9      Montreal           2.214286     2.285714
# 10      Orlando           1.857143     2.357143
# 11       Ottawa           2.270270     3.135135
# 12        Perth           2.000000     2.813953
# 13     San Jose           1.875000     1.950000
# 14      Seattle           2.037037     2.074074
# 15       Sydney           2.454545     3.272727
# 16      Toronto           2.152778     2.236111

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
new_df.columns
# Out:
# Index(['id_x', 'name', 'review_count', 'price', 'is_closed', 'latitude_x',
#        'longitude_x', 'city_x', 'state', 'zip_code', 'country_x', 'rating',
#        'phone', 'term', 'image_x', 'id_y', 'city_y', 'country_y', 'latitude_y',
#        'longitude_y', 'price_range', 'rest_rating', 'rating_text', 'votes',
#        'image_y', 'Price Rating Yelp'],
#       dtype='object')

# %%
bb=new_df[(new_df['rating'].notnull())&(new_df['Price Rating Yelp'].notnull())]
corrfactor=bb.corr()[['review_count','rating','Price Rating Yelp']]
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")
sns.set(style="darkgrid")
#df.applymap(atof)


#figure = plt.subplots(ncols=2, sharey=True)

plt.figure(figsize=(45,10))
sns.lmplot(x="review_count", y="Price Rating Yelp", hue='country_x',data=new_df)
plt.title('Relationship between review count and price rating')
plt.xlabel('Review Count')
plt.ylabel('Price Rating')
#plt.savefig(r"Output Files\Analysis 5\Plot\Review Count Vs Place Rating.jpg")
sns.lmplot(x="rating", y="Price Rating Yelp", hue='country_x',data=new_df)
#plot.text
#plt.yticks([1, 0.1, 0.01, 0.001])
#f = plt.figure()
plt.title('Relationship between place rating and price rating')
plt.xlabel('Rating of place')
plt.ylabel('Price Rating')
#plt.savefig(r"Output Files\Analysis 5\Plot\Rating of place Vs Place Rating.jpg")
print("Plots saved successfully")
plt.show()
# Out:
# Plots saved successfully

# %%
bb=new_df[(new_df['rest_rating'].notnull())&(new_df['price_range'].notnull())]
corrfactor=bb.corr()[['votes','rest_rating','price_range']]
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")
sns.set(style="darkgrid")
#df.applymap(atof)


#figure = plt.subplots(ncols=2, sharey=True)

plt.figure(figsize=(45,10))
sns.lmplot(x="votes", y="price_range", hue='country_x',data=new_df)
plt.title('Relationship between review count and price rating')
plt.xlabel('votes')
plt.ylabel('price_range')
#plt.savefig(r"Output Files\Analysis 5\Plot\Review Count Vs Place Rating.jpg")
sns.lmplot(x="rest_rating", y="price_range", hue='country_x',data=new_df)
#plot.text
#plt.yticks([1, 0.1, 0.01, 0.001])
#f = plt.figure()
plt.title('Relationship between place rating and price rating')
plt.xlabel('Rating of place')
plt.ylabel('Price Rating')
#plt.savefig(r"Output Files\Analysis 5\Plot\Rating of place Vs Place Rating.jpg")
print("Plots saved successfully")
plt.show()
# Out:
# Plots saved successfully

# %%
new_normalized=new_df

# %%
new_normalized['Normalized_Price_Yelp']=(new_normalized['Price Rating Yelp']-new_normalized['Price Rating Yelp'].min())/(new_normalized['Price Rating Yelp'].max()-new_normalized['Price Rating Yelp'].min())

# %%
new_df.columns
# Out:
# Index(['id_x', 'name', 'review_count', 'price', 'is_closed', 'latitude_x',
#        'longitude_x', 'city_x', 'state', 'zip_code', 'country_x', 'rating',
#        'phone', 'term', 'image_x', 'id_y', 'city_y', 'country_y', 'latitude_y',
#        'longitude_y', 'price_range', 'rest_rating', 'rating_text', 'votes',
#        'image_y', 'Price Rating Yelp'],
#       dtype='object')

# %%
new_normalized['Normalized_Review_Count']=((new_normalized['review_count']-new_normalized['review_count'].min())/(new_normalized['review_count'].max()-new_normalized['review_count'].min()))

# %%
new_normalized['Normalized_Zomato_Rating']=(new_normalized['rest_rating']-new_normalized['rest_rating'].min())/(new_normalized['rest_rating'].max()-new_normalized['rest_rating'].min())

# %%
new_normalized['Normalized_Review_Count_Zomato']=((new_normalized['votes']-new_normalized['votes'].min())/(new_normalized['votes'].max()-new_normalized['votes'].min()))

# %%
new_normalized['Overall_Rating_Yelp']=new_normalized['Normalized_Price_Yelp']*new_normalized['Normalized_Review_Count']

# %%
new_normalized['Overall_Rating_Zomato']=new_normalized['Normalized_Zomato_Rating']*new_normalized['Normalized_Review_Count_Zomato']

# %%
new_normalized['Overall_Rating_Yelp_scaled']=new_normalized['Overall_Rating_Yelp']*100
new_normalized['Overall_Rating_Zomato_scaled']=new_normalized['Overall_Rating_Zomato']*100

# %%
new_normalized_sorted_yelp = new_normalized.sort_values('Overall_Rating_Yelp_scaled',ascending=False)

# %%
new_normalized_sorted_zomato = new_normalized.sort_values('Overall_Rating_Zomato_scaled',ascending=False)

# %%
new_normalized_sorted_yelp
# Out:
#                                       id_x                         name  \
# 15                     chin-chin-melbourne                    Chin Chin
# 46          the-hardware-societe-melbourne         The Hardware Societe
# 29                      mamasita-melbourne                     Mamasita
# 33             naked-for-satan-melbourne-3              Naked For Satan
# 17                        cookie-melbourne                       Cookie
# 22                   izakaya-den-melbourne                  Izakaya Den
# 775                 toulouse-petit-seattle               Toulouse Petit
# 18                     gingerboy-melbourne                    Gingerboy
# 3                           mamak-sydney-2                        Mamak
# 12            brother-baba-budan-melbourne           Brother Baba Budan
# 620                home-slice-pizza-austin             Home Slice Pizza
# 353                   antico-pizza-atlanta                 Antico Pizza
# 45               the-grain-store-melbourne              The Grain Store
# 11                 39-pizzeria-melbourne-2                 +39 Pizzeria
# 432                two-urban-licks-atlanta              Two Urban Licks
# 16                          coda-melbourne                         Coda
# 42                   supernormal-melbourne                  Supernormal
# 32                   movida-aqui-melbourne                  MoVida Aqui
# 644   moonshine-patio-bar-and-grill-austin  Moonshine Patio Bar & Grill
# 64                    jamies-italian-perth              Jamie's Italian
# 28                         mamak-melbourne                        Mamak
# 516                 the-purple-pig-chicago               The Purple Pig
# 39           rice-paper-scissors-melbourne          Rice Paper Scissors
# 395                        murphys-atlanta                     Murphy's
# 761                         quinns-seattle                      Quinn's
# 258              bottega-louie-los-angeles                Bottega Louie
# 88                      the-old-crow-perth                 The Old Crow
# 744                           lola-seattle                         Lola
# 122                        the-manx-ottawa                     The Manx
# 55                         balthazar-perth                    Balthazar
# ..                                     ...                          ...
# 463                       cuba-312-chicago                     Cuba 312
# 291          slurpin-ramen-bar-los-angeles           Slurpin' Ramen Bar
# 680                         edison-houston                       Edison
# 289                rodini-park-los-angeles                  Rodini Park
# 682              field-and-tides-houston-2                Field & Tides
# 167                 lasa-by-lamesa-toronto               Lasa by Lamesa
# 488        mother-cluckers-kitchen-chicago      Mother Cluckers Kitchen
# 490                         oriole-chicago                       Oriole
# 512                 the-dearborn-chicago-2                 The Dearborn
# 653                     saigon-cafe-austin                  Saigon Cafe
# 631                     kanji-ramen-austin                  Kanji Ramen
# 632               kemuri-tatsu-ya-austin-2              Kemuri Tatsu-ya
# 633             knotty-deck-and-bar-austin            Knotty Deck & Bar
# 308              go-fish-poke-bar-san-jose             Go Fish Poke Bar
# 510                   the-crab-pad-chicago                 The Crab Pad
# 334                      vn-grill-san-jose                     Vn Grill
# 504                       steakbar-chicago                     SteakBar
# 503                 spotted-monkey-chicago               Spotted Monkey
# 640              lox-box-and-barrel-austin             Lox Box & Barrel
# 305                   enjoy-seoul-san-jose                  Enjoy Seoul
# 642                   me-con-bistro-austin                Me Con Bistro
# 643       mia-italian-tapas-and-bar-austin      Mia Italian Tapas & Bar
# 303  deluxe-eatery-and-drinkery-san-jose-2   Deluxe Eatery And Drinkery
# 646                    old-thousand-austin                 Old Thousand
# 157             hot-pot-restaurant-toronto           Hot Pot Restaurant
# 302                    claw-shack-san-jose                   Claw Shack
# 500                   seoul-taco-chicago-2                   Seoul Taco
# 493       qing-xiang-yuan-dumpling-chicago     Qing Xiang Yuan Dumpling
# 652                     royal-jelly-austin                  Royal Jelly
# 578             new-asia-restaurant-lowell          New Asia Restaurant
#
#      review_count price is_closed  latitude_x  longitude_x       city_x state  \
# 15            279    $$     False  -37.815488   144.970222    Melbourne   VIC
# 46            153    $$     False  -37.811965   144.960602    Melbourne   VIC
# 29             95    $$     False  -37.813768   144.973458    Melbourne   VIC
# 33             97    $$     False  -37.798850   144.978180    Melbourne   VIC
# 17             87    $$     False  -37.811990   144.965210    Melbourne   VIC
# 22             58   $$$     False  -37.813674   144.968709    Melbourne   VIC
# 775          2888    $$     False   47.624851  -122.357127      Seattle    WA
# 18             34   $$$     False  -37.811250   144.970930    Melbourne   VIC
# 3             214    $$     False  -33.877862   151.204231       Sydney   NSW
# 12            106     $     False  -37.813553   144.962143    Melbourne   VIC
# 620          2734    $$     False   30.249200   -97.749430       Austin    TX
# 353          2377    $$     False   33.784642   -84.405652      Atlanta    GA
# 45             73    $$     False  -37.819482   144.956886    Melbourne   VIC
# 11             68    $$     False  -37.814183   144.962870    Melbourne   VIC
# 432          1634   $$$     False   33.768456   -84.361274      Atlanta    GA
# 16             48   $$$     False  -37.815819   144.969943    Melbourne   VIC
# 42             74   $$$     False  -37.816026   144.968478    Melbourne   VIC
# 32             44   $$$     False  -37.815262   144.958923    Melbourne   VIC
# 644          2466    $$     False   30.263863   -97.738087       Austin    TX
# 64            126    $$     False  -31.951798   115.857943        Perth    WA
# 28             70    $$     False  -37.812615   144.961643    Melbourne   VIC
# 516          4928    $$     False   41.891020   -87.624562      Chicago    IL
# 39             71    $$     False  -37.811263   144.971232    Melbourne   VIC
# 395           790    $$     False   33.782090   -84.354870      Atlanta    GA
# 761          1198    $$     False   47.613860  -122.319220      Seattle    WA
# 258         13016    $$     False   34.046930  -118.256601  Los Angeles    CA
# 88             68    $$     False  -31.946692   115.862566        Perth    WA
# 744          2832    $$     False   47.613252  -122.340061      Seattle    WA
# 122            99    $$     False   45.415139   -75.687944       Ottawa    ON
# 55             16  $$$$     False  -31.956459   115.858290        Perth    WA
# ..            ...   ...       ...         ...          ...          ...   ...
# 463           166    $$     False   41.943481   -87.680633      Chicago    IL
# 291          1484    $$     False   34.057361  -118.306770  Los Angeles    CA
# 680           125    $$     False   29.798390   -95.363160      Houston    TX
# 289           752     $     False   34.165067  -118.372182  Los Angeles    CA
# 682            54    $$     False   29.791096   -95.389679      Houston    TX
# 167            24    $$     False   43.682280   -79.423962      Toronto    ON
# 488           374    $$     False   41.975269   -87.752248      Chicago    IL
# 490            89  $$$$     False   41.886198   -87.644950      Chicago    IL
# 512           288    $$     False   41.884258   -87.629397      Chicago    IL
# 653            94     $     False   30.412001   -97.927223       Austin    TX
# 631           124    $$     False   30.430770   -97.764580       Austin    TX
# 632            52    $$     False   30.253794   -97.712952       Austin    TX
# 633            39    $$     False   30.391654   -97.749918       Austin    TX
# 308           692    $$     False   37.303987  -122.032909     San Jose    CA
# 510           140    $$     False   41.927440   -87.704240      Chicago    IL
# 334           598     $     False   37.383294  -121.896709     San Jose    CA
# 504            90   $$$     False   41.909240   -87.634980      Chicago    IL
# 503           105    $$     False   41.877200   -87.634770      Chicago    IL
# 640            59    $$     False   30.230030   -97.934050       Austin    TX
# 305           279    $$     False   37.331686  -121.857493     San Jose    CA
# 642           156    $$     False   30.212993   -97.829482       Austin    TX
# 643           148    $$     False   30.401048   -97.722942       Austin    TX
# 303           288    $$     False   37.335276  -121.887778     San Jose    CA
# 646            80    $$     False   30.269620   -97.729920       Austin    TX
# 157            12    $$     False   43.697467   -79.441352      Toronto    ON
# 302           754    $$     False   37.372845  -121.873863     San Jose    CA
# 500           262     $     False   41.895923   -87.631396      Chicago    IL
# 493           292    $$     False   41.855049   -87.632187      Chicago    IL
# 652           131    $$     False   30.339100   -97.717030       Austin    TX
# 578            19    $$     False   42.645420   -71.314537       Lowell    MA
#
#     zip_code              ...               \
# 15      3000              ...
# 46      3000              ...
# 29      3000              ...
# 33      3065              ...
# 17      3000              ...
# 22      3000              ...
# 775    98109              ...
# 18      3000              ...
# 3       2000              ...
# 12      3000              ...
# 620    78704              ...
# 353    30318              ...
# 45      3000              ...
# 11      3000              ...
# 432    30306              ...
# 16      3000              ...
# 42      3000              ...
# 32      3000              ...
# 644    78701              ...
# 64      6000              ...
# 28      3000              ...
# 516    60611              ...
# 39      3000              ...
# 395    30306              ...
# 761    98122              ...
# 258    90017              ...
# 88      6000              ...
# 744    98121              ...
# 122  K2P 1N1              ...
# 55      6000              ...
# ..       ...              ...
# 463    60618              ...
# 291    90005              ...
# 680    77009              ...
# 289    91601              ...
# 682    77008              ...
# 167  M6C 1A9              ...
# 488    60630              ...
# 490    60661              ...
# 512    60602              ...
# 653    78734              ...
# 631    78759              ...
# 632    78702              ...
# 633    78759              ...
# 308    95129              ...
# 510    60647              ...
# 334    95131              ...
# 504    60610              ...
# 503    60606              ...
# 640    78737              ...
# 305    95122              ...
# 642    78745              ...
# 643    78758              ...
# 303    95113              ...
# 646    78702              ...
# 157  M6E 2G8              ...
# 302    95133              ...
# 500    60654              ...
# 493    60616              ...
# 652    78752              ...
# 578    01852              ...
#
#                                                image_y  Price Rating Yelp  \
# 15   https://b.zmtcdn.com/data/pictures/2/16577492/...                2.0
# 46   https://b.zmtcdn.com/data/pictures/5/16573665/...                2.0
# 29   https://b.zmtcdn.com/data/pictures/8/16575238/...                2.0
# 33   https://b.zmtcdn.com/data/pictures/4/16576154/...                2.0
# 17   https://b.zmtcdn.com/data/pictures/7/16571167/...                2.0
# 22   https://b.zmtcdn.com/data/pictures/0/16574110/...                3.0
# 775  https://b.zmtcdn.com/data/pictures/9/16727499/...                2.0
# 18   https://b.zmtcdn.com/data/pictures/1/16571411/...                3.0
# 3    https://b.zmtcdn.com/data/pictures/1/16558421/...                2.0
# 12   https://b.zmtcdn.com/data/pictures/8/16572688/...                1.0
# 620  https://b.zmtcdn.com/data/pictures/9/16912869/...                2.0
# 353  https://b.zmtcdn.com/data/pictures/9/16906739/...                2.0
# 45   https://b.zmtcdn.com/data/pictures/2/16581462/...                2.0
# 11   https://b.zmtcdn.com/data/pictures/2/16572962/...                2.0
# 432  https://b.zmtcdn.com/data/pictures/9/16895009/...                3.0
# 16   https://b.zmtcdn.com/data/pictures/9/16573419/...                3.0
# 42   https://b.zmtcdn.com/data/pictures/7/16582897/...                3.0
# 32   https://b.zmtcdn.com/data/pictures/1/16574211/...                3.0
# 644  https://b.zmtcdn.com/data/pictures/9/16913359/...                2.0
# 64   https://b.zmtcdn.com/data/pictures/8/16599918/...                2.0
# 28   https://b.zmtcdn.com/data/pictures/7/16580267/...                2.0
# 516  https://b.zmtcdn.com/data/pictures/8/16752778/...                2.0
# 39   https://b.zmtcdn.com/data/pictures/7/16582887/...                2.0
# 395  https://b.zmtcdn.com/data/pictures/8/16894848/...                2.0
# 761  https://b.zmtcdn.com/data/pictures/3/16720983/...                2.0
# 258  https://b.zmtcdn.com/data/pictures/4/16831684/...                2.0
# 88   https://b.zmtcdn.com/data/pictures/8/16600278/...                2.0
# 744  https://b.zmtcdn.com/data/pictures/5/16718075/...                2.0
# 122  https://b.zmtcdn.com/data/pictures/3/16663263/...                2.0
# 55   https://b.zmtcdn.com/data/pictures/6/16595766/...                4.0
# ..                                                 ...                ...
# 463  https://b.zmtcdn.com/data/pictures/1/18076981/...                2.0
# 291                                                NaN                2.0
# 680                                                NaN                2.0
# 289  https://b.zmtcdn.com/data/pictures/7/18412677/...                1.0
# 682                                                NaN                2.0
# 167                                                NaN                2.0
# 488  https://b.zmtcdn.com/data/pictures/1/17762381/...                2.0
# 490                                                NaN                4.0
# 512                                                NaN                2.0
# 653  https://b.zmtcdn.com/data/pictures/0/18080410/...                1.0
# 631                                                NaN                2.0
# 632                                                NaN                2.0
# 633  https://b.zmtcdn.com/data/pictures/9/18098949/...                2.0
# 308  https://b.zmtcdn.com/data/pictures/7/18408217/...                2.0
# 510                                                NaN                2.0
# 334  https://b.zmtcdn.com/data/pictures/0/17770810/...                1.0
# 504  https://b.zmtcdn.com/data/pictures/chains/8/18...                3.0
# 503                                                NaN                2.0
# 640  https://b.zmtcdn.com/data/pictures/3/17881473/...                2.0
# 305  https://b.zmtcdn.com/data/pictures/7/16861917/...                2.0
# 642  https://b.zmtcdn.com/data/pictures/2/18422842/...                2.0
# 643                                                NaN                2.0
# 303                                                NaN                2.0
# 646  https://b.zmtcdn.com/data/pictures/5/18174935/...                2.0
# 157                                                NaN                2.0
# 302  https://b.zmtcdn.com/data/pictures/2/17769022/...                2.0
# 500                                                NaN                1.0
# 493  https://b.zmtcdn.com/data/pictures/7/18078107/...                2.0
# 652  https://b.zmtcdn.com/data/pictures/7/17969797/...                2.0
# 578                                                NaN                2.0
#
#      Normalized_Price_Yelp Normalized_Review_Count Normalized_Zomato_Rating  \
# 15                0.333333                0.021210                 0.857143
# 46                0.333333                0.011527                 0.857143
# 29                0.333333                0.007070                 0.857143
# 33                0.333333                0.007224                 0.918367
# 17                0.333333                0.006455                 0.816327
# 22                0.666667                0.004227                 0.877551
# 775               0.333333                0.221701                 0.959184
# 18                0.666667                0.002382                 0.836735
# 3                 0.333333                0.016215                 0.877551
# 12                0.000000                0.007915                 0.938776
# 620               0.333333                0.209867                 1.000000
# 353               0.333333                0.182433                 0.979592
# 45                0.333333                0.005379                 0.795918
# 11                0.333333                0.004995                 0.857143
# 432               0.666667                0.125336                 0.959184
# 16                0.666667                0.003458                 0.897959
# 42                0.666667                0.005456                 0.836735
# 32                0.666667                0.003151                 0.877551
# 644               0.333333                0.189272                 0.959184
# 64                0.333333                0.009452                 0.632653
# 28                0.333333                0.005149                 0.755102
# 516               0.333333                0.378468                 1.000000
# 39                0.333333                0.005226                 0.938776
# 395               0.333333                0.060478                 0.918367
# 761               0.333333                0.091831                 0.897959
# 258               0.333333                1.000000                 1.000000
# 88                0.333333                0.004995                 0.816327
# 744               0.333333                0.217398                 0.857143
# 122               0.333333                0.007377                 0.959184
# 55                1.000000                0.000999                 0.857143
# ..                     ...                     ...                      ...
# 463               0.333333                0.012526                 0.000000
# 291               0.333333                0.113809                 0.000000
# 680               0.333333                0.009375                 0.000000
# 289               0.000000                0.057558                 0.000000
# 682               0.333333                0.003919                 0.000000
# 167               0.333333                0.001614                 0.000000
# 488               0.333333                0.028510                 0.000000
# 490               1.000000                0.006609                 0.000000
# 512               0.333333                0.021901                 0.000000
# 653               0.000000                0.006993                 0.000000
# 631               0.333333                0.009298                 0.000000
# 632               0.333333                0.003765                 0.000000
# 633               0.333333                0.002766                 0.000000
# 308               0.333333                0.052947                 0.000000
# 510               0.333333                0.010528                 0.000000
# 334               0.000000                0.045724                 0.000000
# 504               0.666667                0.006686                 0.000000
# 503               0.333333                0.007838                 0.000000
# 640               0.333333                0.004303                 0.000000
# 305               0.333333                0.021210                 0.000000
# 642               0.333333                0.011757                 0.000000
# 643               0.333333                0.011143                 0.000000
# 303               0.333333                0.021901                 0.000000
# 646               0.333333                0.005917                 0.000000
# 157               0.333333                0.000692                 0.000000
# 302               0.333333                0.057712                 0.000000
# 500               0.000000                0.019903                 0.000000
# 493               0.333333                0.022209                 0.000000
# 652               0.333333                0.009836                 0.000000
# 578               0.333333                0.001230                 0.000000
#
#      Normalized_Review_Count_Zomato Overall_Rating_Yelp Overall_Rating_Zomato  \
# 15                         1.000000            0.007070              0.857143
# 46                         0.847731            0.003842              0.726627
# 29                         0.797002            0.002357              0.683144
# 33                         0.471070            0.002408              0.432615
# 17                         0.417666            0.002152              0.340952
# 22                         0.314182            0.002818              0.275710
# 775                        0.241896            0.073900              0.232023
# 18                         0.276661            0.001588              0.231492
# 3                          0.251459            0.005405              0.220668
# 12                         0.233306            0.000000              0.219022
# 620                        0.208023            0.069956              0.208023
# 353                        0.212156            0.060811              0.207826
# 45                         0.261102            0.001793              0.207816
# 11                         0.221718            0.001665              0.190044
# 432                        0.195381            0.083557              0.187406
# 16                         0.189222            0.002305              0.169914
# 42                         0.193841            0.003637              0.162194
# 32                         0.181524            0.002100              0.159296
# 644                        0.164100            0.063091              0.157403
# 64                         0.234684            0.003151              0.148474
# 28                         0.194408            0.001716              0.146798
# 516                        0.141815            0.126156              0.141815
# 39                         0.149190            0.001742              0.140056
# 395                        0.151621            0.020159              0.139244
# 761                        0.153971            0.030610              0.138260
# 258                        0.137196            0.333333              0.137196
# 88                         0.164587            0.001665              0.134356
# 744                        0.151459            0.072466              0.129822
# 122                        0.133468            0.002459              0.128021
# 55                         0.146759            0.000999              0.125793
# ..                              ...                 ...                   ...
# 463                        0.000081            0.004175              0.000000
# 291                        0.000243            0.037936              0.000000
# 680                        0.000081            0.003125              0.000000
# 289                        0.000081            0.000000              0.000000
# 682                        0.000081            0.001306              0.000000
# 167                        0.000243            0.000538              0.000000
# 488                        0.000081            0.009503              0.000000
# 490                        0.000162            0.006609              0.000000
# 512                        0.000081            0.007300              0.000000
# 653                        0.000162            0.000000              0.000000
# 631                        0.000000            0.003099              0.000000
# 632                        0.000081            0.001255              0.000000
# 633                        0.000000            0.000922              0.000000
# 308                        0.000000            0.017649              0.000000
# 510                        0.000081            0.003509              0.000000
# 334                        0.000081            0.000000              0.000000
# 504                        0.000162            0.004457              0.000000
# 503                        0.000162            0.002613              0.000000
# 640                        0.000081            0.001434              0.000000
# 305                        0.000081            0.007070              0.000000
# 642                        0.000000            0.003919              0.000000
# 643                        0.000081            0.003714              0.000000
# 303                        0.000081            0.007300              0.000000
# 646                        0.000000            0.001972              0.000000
# 157                        0.000000            0.000231              0.000000
# 302                        0.000081            0.019237              0.000000
# 500                        0.000000            0.000000              0.000000
# 493                        0.000162            0.007403              0.000000
# 652                        0.000162            0.003279              0.000000
# 578                        0.000081            0.000410              0.000000
#
#      Overall_Rating_Yelp_scaled  Overall_Rating_Zomato_scaled
# 15                     0.706985                     85.714286
# 46                     0.384231                     72.662653
# 29                     0.235662                     68.314425
# 33                     0.240785                     43.261502
# 17                     0.215169                     34.095194
# 22                     0.281770                     27.571032
# 775                    7.390046                     23.202296
# 18                     0.158816                     23.149208
# 3                      0.540485                     22.066781
# 12                     0.000000                     21.902226
# 620                    6.995569                     20.802269
# 353                    6.081098                     20.782589
# 45                     0.179308                     20.781596
# 11                     0.166500                     19.004399
# 432                    8.355747                     18.740615
# 16                     0.230539                     16.991367
# 42                     0.363739                     16.219363
# 32                     0.210046                     15.929613
# 644                    6.309076                     15.740251
# 64                     0.315070                     14.847352
# 28                     0.171623                     14.679820
# 516                   12.615590                     14.181524
# 39                     0.174185                     14.005557
# 395                    2.015933                     13.924354
# 761                    3.061042                     13.825952
# 258                   33.333333                     13.719611
# 88                     0.166500                     13.435650
# 744                    7.246600                     12.982172
# 122                    0.245908                     12.802071
# 55                     0.099900                     12.579301
# ..                          ...                           ...
# 463                    0.417531                      0.000000
# 291                    3.793642                      0.000000
# 680                    0.312508                      0.000000
# 289                    0.000000                      0.000000
# 682                    0.130639                      0.000000
# 167                    0.053792                      0.000000
# 488                    0.950332                      0.000000
# 490                    0.660878                      0.000000
# 512                    0.730039                      0.000000
# 653                    0.000000                      0.000000
# 631                    0.309946                      0.000000
# 632                    0.125516                      0.000000
# 633                    0.092215                      0.000000
# 308                    1.764902                      0.000000
# 510                    0.350931                      0.000000
# 334                    0.000000                      0.000000
# 504                    0.445708                      0.000000
# 503                    0.261277                      0.000000
# 640                    0.143446                      0.000000
# 305                    0.706985                      0.000000
# 642                    0.391916                      0.000000
# 643                    0.371423                      0.000000
# 303                    0.730039                      0.000000
# 646                    0.197239                      0.000000
# 157                    0.023054                      0.000000
# 302                    1.923717                      0.000000
# 500                    0.000000                      0.000000
# 493                    0.740285                      0.000000
# 652                    0.327877                      0.000000
# 578                    0.040985                      0.000000
#
# [779 rows x 34 columns]

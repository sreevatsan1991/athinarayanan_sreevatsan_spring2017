# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
reviews=pd.read_csv("Other Files\\Reviews_Yelp.csv")
data=pd.read_csv("Other Files\\YelpData.csv")

# %%
reviews.head()
# Out:
#                         id  rating         time_created  \
# 0          80-proof-sydney       4  2015-04-15 03:37:53
# 1          80-proof-sydney       5  2016-04-13 02:45:30
# 2          80-proof-sydney       4  2013-06-19 17:15:22
# 3  alpha-restaurant-sydney       5  2016-07-08 19:34:56
# 4  alpha-restaurant-sydney       4  2016-10-22 05:36:00
#
#                                                 text
# 0  Right under my nose! like literally. My collea...
# 1  Great food!  Good portions at a reasonable pri...
# 2  Very chill and cozy place to hang out (Can't c...
# 3  If you're into something fancy this place is y...
# 4  well if u want to take someone special on date...

# %%
review_city=pd.merge(reviews,data,how='left',on="id")

# %%
review_city=review_city[['id','rating_x','time_created','text','city']]

# %%
review_city_boston=review_city[review_city['city']=='Boston']

# %%
len(review_city_boston)
# Out:
# 240

# %%
reviews_boston=review_city_boston

# %%
reviews_boston.columns
# Out:
# Index(['id', 'rating_x', 'time_created', 'text', 'city'], dtype='object')

# %%
reviews_boston=reviews_boston.reset_index()

# %%
pos_count = 0
neg_count = 0
reviews_boston["positivity"]=0.000
reviews_boston["negativity"]=0.000
#print(df)
for i in range(0,len(reviews_boston)):
    blob = TextBlob(reviews_boston["text"][i], analyzer=NaiveBayesAnalyzer())
    reviews_boston["positivity"][i]=blob.sentiment.p_pos*100
    reviews_boston["negativity"][i]=blob.sentiment.p_neg*100
    print(blob.sentiment)
    if blob.sentiment.classification == 'pos':
        pos_count+=blob.sentiment.p_pos
    if blob.sentiment.classification == 'neg':
        neg_count+=blob.sentiment.p_neg
    print(i)
pos_count=float(pos_count/len(reviews_boston))
neg_count=float(neg_count/len(reviews_boston))
print("Overall positivity score:"+str(pos_count))
print("Overall negativity score:"+str(neg_count))
#print(df["Type"][i])
# Out:
# C:\Users\Nimi\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Nimi\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Sentiment(classification='pos', p_pos=0.9911855827264499, p_neg=0.008814417273545457)
# 0
# Sentiment(classification='neg', p_pos=0.3209625195740948, p_neg=0.6790374804259035)
# 1
# Sentiment(classification='pos', p_pos=0.6941633596030242, p_neg=0.30583664039698016)
# 2
# Sentiment(classification='pos', p_pos=0.9785712675389453, p_neg=0.021428732461053795)
# 3
# Sentiment(classification='pos', p_pos=0.8830735524760603, p_neg=0.11692644752394077)
# 4
# Sentiment(classification='pos', p_pos=0.7191289437582211, p_neg=0.2808710562417791)
# 5
# Sentiment(classification='pos', p_pos=0.9379685516310852, p_neg=0.0620314483689158)
# 6
# Sentiment(classification='pos', p_pos=0.742937358886102, p_neg=0.25706264111389426)
# 7
# Sentiment(classification='pos', p_pos=0.8427168489312703, p_neg=0.15728315106872642)
# 8
# Sentiment(classification='pos', p_pos=0.7577888200624815, p_neg=0.24221117993752053)
# 9
# Sentiment(classification='pos', p_pos=0.7475444273000809, p_neg=0.2524555726999206)
# 10
# Sentiment(classification='pos', p_pos=0.8249295305935669, p_neg=0.17507046940643523)
# 11
# Sentiment(classification='pos', p_pos=0.7632700734099362, p_neg=0.23672992659006578)
# 12
# Sentiment(classification='pos', p_pos=0.7080510281844854, p_neg=0.2919489718155148)
# 13
# Sentiment(classification='pos', p_pos=0.7283677863655211, p_neg=0.2716322136344783)
# 14
# Sentiment(classification='pos', p_pos=0.970637200667995, p_neg=0.029362799332007236)
# 15
# Sentiment(classification='pos', p_pos=0.9751926912310751, p_neg=0.024807308768928244)
# 16
# Sentiment(classification='pos', p_pos=0.9857564730299718, p_neg=0.014243526970027379)
# 17
# Sentiment(classification='pos', p_pos=0.8548662348931102, p_neg=0.14513376510688816)
# 18
# Sentiment(classification='pos', p_pos=0.668610450463773, p_neg=0.3313895495362274)
# 19
# Sentiment(classification='pos', p_pos=0.9356905408242002, p_neg=0.0643094591758015)
# 20
# Sentiment(classification='neg', p_pos=0.059348830251497675, p_neg=0.9406511697485014)
# 21
# Sentiment(classification='pos', p_pos=0.953651319853262, p_neg=0.046348680146734066)
# 22
# Sentiment(classification='pos', p_pos=0.9188386987495468, p_neg=0.08116130125045387)
# 23
# Sentiment(classification='neg', p_pos=0.42051955945574887, p_neg=0.5794804405442552)
# 24
# Sentiment(classification='pos', p_pos=0.8462222498202484, p_neg=0.1537777501797523)
# 25
# Sentiment(classification='pos', p_pos=0.7117244654464713, p_neg=0.2882755345535263)
# 26
# Sentiment(classification='neg', p_pos=0.1240158054871302, p_neg=0.8759841945128687)
# 27
# Sentiment(classification='pos', p_pos=0.9290171802852268, p_neg=0.07098281971477506)
# 28
# Sentiment(classification='pos', p_pos=0.7804358648836037, p_neg=0.2195641351163939)
# 29
# Sentiment(classification='neg', p_pos=0.21864487680009487, p_neg=0.781355123199906)
# 30
# Sentiment(classification='pos', p_pos=0.9332093122695162, p_neg=0.06679068773048581)
# 31
# Sentiment(classification='pos', p_pos=0.7351205064978822, p_neg=0.2648794935021159)
# 32
# Sentiment(classification='pos', p_pos=0.996470303223073, p_neg=0.003529696776926541)
# 33
# Sentiment(classification='pos', p_pos=0.9195059860407453, p_neg=0.08049401395925036)
# 34
# Sentiment(classification='pos', p_pos=0.9772866139125066, p_neg=0.022713386087495874)
# 35
# Sentiment(classification='pos', p_pos=0.990062574427961, p_neg=0.009937425572039606)
# 36
# Sentiment(classification='pos', p_pos=0.901546277967129, p_neg=0.09845372203287235)
# 37
# Sentiment(classification='pos', p_pos=0.9921492798367894, p_neg=0.007850720163214005)
# 38
# Sentiment(classification='pos', p_pos=0.979576750516842, p_neg=0.02042324948315668)
# 39
# Sentiment(classification='pos', p_pos=0.9298362087299658, p_neg=0.07016379127003304)
# 40
# Sentiment(classification='neg', p_pos=0.2846325122216707, p_neg=0.7153674877783294)
# 41
# Sentiment(classification='pos', p_pos=0.8885043331887171, p_neg=0.11149566681128735)
# 42
# Sentiment(classification='neg', p_pos=0.3799380232614264, p_neg=0.6200619767385755)
# 43
# Sentiment(classification='neg', p_pos=0.0034366977094378135, p_neg=0.9965633022905644)
# 44
# Sentiment(classification='pos', p_pos=0.9089541852546759, p_neg=0.09104581474532825)
# 45
# Sentiment(classification='pos', p_pos=0.773158067833814, p_neg=0.22684193216618542)
# 46
# Sentiment(classification='pos', p_pos=0.8948207053871302, p_neg=0.10517929461287093)
# 47
# Sentiment(classification='pos', p_pos=0.9463031400527774, p_neg=0.05369685994722127)
# 48
# Sentiment(classification='pos', p_pos=0.8536085066430321, p_neg=0.1463914933569632)
# 49
# Sentiment(classification='neg', p_pos=0.06176261183023445, p_neg=0.9382373881697676)
# 50
# Sentiment(classification='pos', p_pos=0.9762740659959993, p_neg=0.02372593400400258)
# 51
# Sentiment(classification='pos', p_pos=0.6783100637856377, p_neg=0.3216899362143638)
# 52
# Sentiment(classification='pos', p_pos=0.8308856940192031, p_neg=0.16911430598080116)
# 53
# Sentiment(classification='pos', p_pos=0.6014598650805729, p_neg=0.3985401349194252)
# 54
# Sentiment(classification='pos', p_pos=0.6317181801160711, p_neg=0.368281819883928)
# 55
# Sentiment(classification='pos', p_pos=0.8957049228027096, p_neg=0.10429507719728871)
# 56
# Sentiment(classification='pos', p_pos=0.9179740330800134, p_neg=0.08202596691998543)
# 57
# Sentiment(classification='neg', p_pos=0.41507675756462886, p_neg=0.5849232424353702)
# 58
# Sentiment(classification='neg', p_pos=0.1970583183779634, p_neg=0.8029416816220334)
# 59
# Sentiment(classification='neg', p_pos=0.11237487509149832, p_neg=0.8876251249085026)
# 60
# Sentiment(classification='pos', p_pos=0.5436573644880962, p_neg=0.45634263551190557)
# 61
# Sentiment(classification='pos', p_pos=0.9935987542880443, p_neg=0.006401245711956162)
# 62
# Sentiment(classification='neg', p_pos=0.18105243402416177, p_neg=0.8189475659758376)
# 63
# Sentiment(classification='pos', p_pos=0.7153193521196698, p_neg=0.2846806478803282)
# 64
# Sentiment(classification='neg', p_pos=0.4510252948400632, p_neg=0.5489747051599361)
# 65
# Sentiment(classification='pos', p_pos=0.965141664546999, p_neg=0.03485833545300079)
# 66
# Sentiment(classification='neg', p_pos=0.44965453135661926, p_neg=0.5503454686433806)
# 67
# Sentiment(classification='neg', p_pos=0.09358469422616995, p_neg=0.906415305773832)
# 68
# Sentiment(classification='pos', p_pos=0.8481547224116505, p_neg=0.15184527758835203)
# 69
# Sentiment(classification='pos', p_pos=0.8157096024711226, p_neg=0.18429039752887894)
# 70
# Sentiment(classification='pos', p_pos=0.8432371619830661, p_neg=0.1567628380169327)
# 71
# Sentiment(classification='neg', p_pos=0.41912205337309655, p_neg=0.5808779466269024)
# 72
# Sentiment(classification='pos', p_pos=0.9238328722363367, p_neg=0.07616712776366408)
# 73
# Sentiment(classification='pos', p_pos=0.8358232387655142, p_neg=0.1641767612344872)
# 74
# Sentiment(classification='neg', p_pos=0.11136308978573983, p_neg=0.8886369102142582)
# 75
# Sentiment(classification='pos', p_pos=0.8336539388578587, p_neg=0.166346061142141)
# 76
# Sentiment(classification='pos', p_pos=0.8459653178843187, p_neg=0.1540346821156811)
# 77
# Sentiment(classification='pos', p_pos=0.8174088002521769, p_neg=0.18259119974782453)
# 78
# Sentiment(classification='pos', p_pos=0.920216032261107, p_neg=0.07978396773889443)
# 79
# Sentiment(classification='pos', p_pos=0.6444850560545649, p_neg=0.35551494394543637)
# 80
# Sentiment(classification='pos', p_pos=0.8147954168534912, p_neg=0.1852045831465111)
# 81
# Sentiment(classification='neg', p_pos=0.23534135820648547, p_neg=0.7646586417935163)
# 82
# Sentiment(classification='pos', p_pos=0.8776960829854501, p_neg=0.12230391701455204)
# 83
# Sentiment(classification='pos', p_pos=0.7031872652357396, p_neg=0.2968127347642628)
# 84
# Sentiment(classification='pos', p_pos=0.9577817291425607, p_neg=0.042218270857442355)
# 85
# Sentiment(classification='pos', p_pos=0.6096685320995168, p_neg=0.39033146790048423)
# 86
# Sentiment(classification='neg', p_pos=0.4023287488657592, p_neg=0.597671251134242)
# 87
# Sentiment(classification='pos', p_pos=0.9447200780337685, p_neg=0.055279921966233526)
# 88
# Sentiment(classification='pos', p_pos=0.5821882688109485, p_neg=0.4178117311890508)
# 89
# Sentiment(classification='pos', p_pos=0.9771694095904897, p_neg=0.022830590409513588)
# 90
# Sentiment(classification='pos', p_pos=0.793609569870179, p_neg=0.20639043012982322)
# 91
# Sentiment(classification='pos', p_pos=0.6175768845986761, p_neg=0.38242311540132334)
# 92
# Sentiment(classification='pos', p_pos=0.8373880191735584, p_neg=0.16261198082644032)
# 93
# Sentiment(classification='pos', p_pos=0.675812040217815, p_neg=0.32418795978218184)
# 94
# Sentiment(classification='pos', p_pos=0.8816233541009941, p_neg=0.11837664589900694)
# 95
# Sentiment(classification='pos', p_pos=0.7740618092236466, p_neg=0.22593819077635258)
# 96
# Sentiment(classification='pos', p_pos=0.565144399416625, p_neg=0.4348556005833767)
# 97
# Sentiment(classification='neg', p_pos=0.22949680890313479, p_neg=0.7705031910968664)
# 98
# Sentiment(classification='pos', p_pos=0.7380128488422001, p_neg=0.2619871511578007)
# 99
# Sentiment(classification='pos', p_pos=0.9675358325159397, p_neg=0.03246416748406258)
# 100
# Sentiment(classification='pos', p_pos=0.918770553776788, p_neg=0.08122944622321684)
# 101
# Sentiment(classification='neg', p_pos=0.412376966055697, p_neg=0.5876230339443013)
# 102
# Sentiment(classification='pos', p_pos=0.995877599586822, p_neg=0.004122400413176479)
# 103
# Sentiment(classification='pos', p_pos=0.9779437803302893, p_neg=0.02205621966971203)
# 104
# Sentiment(classification='neg', p_pos=0.49584574754088234, p_neg=0.5041542524591175)
# 105
# Sentiment(classification='neg', p_pos=0.45050431184095535, p_neg=0.5494956881590446)
# 106
# Sentiment(classification='pos', p_pos=0.8683295880231575, p_neg=0.13167041197684015)
# 107
# Sentiment(classification='pos', p_pos=0.8795826667283007, p_neg=0.12041733327170169)
# 108
# Sentiment(classification='pos', p_pos=0.6810756145902579, p_neg=0.3189243854097429)
# 109
# Sentiment(classification='pos', p_pos=0.8324397701696236, p_neg=0.16756022983037552)
# 110
# Sentiment(classification='pos', p_pos=0.8982678769701343, p_neg=0.10173212302986435)
# 111
# Sentiment(classification='neg', p_pos=0.2938106638189402, p_neg=0.7061893361810577)
# 112
# Sentiment(classification='pos', p_pos=0.9396672860652163, p_neg=0.060332713934787535)
# 113
# Sentiment(classification='pos', p_pos=0.9130223284723589, p_neg=0.08697767152764313)
# 114
# Sentiment(classification='pos', p_pos=0.7899322768619996, p_neg=0.21006772313799943)
# 115
# Sentiment(classification='pos', p_pos=0.767190988216051, p_neg=0.2328090117839455)
# 116
# Sentiment(classification='pos', p_pos=0.983809125426658, p_neg=0.016190874573342416)
# 117
# Sentiment(classification='neg', p_pos=0.4944446052273249, p_neg=0.5055553947726766)
# 118
# Sentiment(classification='neg', p_pos=0.4731587152362204, p_neg=0.5268412847637817)
# 119
# Sentiment(classification='neg', p_pos=0.46490401024806616, p_neg=0.5350959897519315)
# 120
# Sentiment(classification='pos', p_pos=0.936082184420896, p_neg=0.0639178155791012)
# 121
# Sentiment(classification='neg', p_pos=0.48500956525409683, p_neg=0.5149904347459023)
# 122
# Sentiment(classification='neg', p_pos=0.2630563809482165, p_neg=0.736943619051784)
# 123
# Sentiment(classification='pos', p_pos=0.7728043134117745, p_neg=0.22719568658822736)
# 124
# Sentiment(classification='pos', p_pos=0.9996361194024772, p_neg=0.00036388059751954005)
# 125
# Sentiment(classification='pos', p_pos=0.9629599095531512, p_neg=0.03704009044684807)
# 126
# Sentiment(classification='pos', p_pos=0.586856611795808, p_neg=0.4131433882041928)
# 127
# Sentiment(classification='neg', p_pos=0.08656892686594003, p_neg=0.9134310731340578)
# 128
# Sentiment(classification='pos', p_pos=0.977127377222652, p_neg=0.022872622777346946)
# 129
# Sentiment(classification='pos', p_pos=0.5807116352407146, p_neg=0.4192883647592878)
# 130
# Sentiment(classification='pos', p_pos=0.8807090906451236, p_neg=0.11929090935488107)
# 131
# Sentiment(classification='pos', p_pos=0.9025689759110974, p_neg=0.09743102408890429)
# 132
# Sentiment(classification='pos', p_pos=0.9727674414326862, p_neg=0.02723255856731125)
# 133
# Sentiment(classification='pos', p_pos=0.6992181199890166, p_neg=0.30078188001098544)
# 134
# Sentiment(classification='neg', p_pos=0.0681285136487602, p_neg=0.9318714863512427)
# 135
# Sentiment(classification='pos', p_pos=0.8958264254618332, p_neg=0.10417357453816894)
# 136
# Sentiment(classification='neg', p_pos=0.31770364327393263, p_neg=0.6822963567260628)
# 137
# Sentiment(classification='pos', p_pos=0.6192947824859197, p_neg=0.3807052175140793)
# 138
# Sentiment(classification='pos', p_pos=0.8533102906609276, p_neg=0.14668970933907488)
# 139
# Sentiment(classification='pos', p_pos=0.9940962598354594, p_neg=0.005903740164545684)
# 140
# Sentiment(classification='pos', p_pos=0.9976173518539935, p_neg=0.002382648146008185)
# 141
# Sentiment(classification='pos', p_pos=0.5579593253444473, p_neg=0.4420406746555513)
# 142
# Sentiment(classification='neg', p_pos=0.38617826554407964, p_neg=0.6138217344559211)
# 143
# Sentiment(classification='neg', p_pos=0.1324377480530241, p_neg=0.8675622519469803)
# 144
# Sentiment(classification='pos', p_pos=0.7052578706984813, p_neg=0.29474212930151844)
# 145
# Sentiment(classification='neg', p_pos=0.3548444424872623, p_neg=0.6451555575127373)
# 146
# Sentiment(classification='pos', p_pos=0.9959524003448038, p_neg=0.004047599655193849)
# 147
# Sentiment(classification='pos', p_pos=0.8910595266152064, p_neg=0.1089404733847949)
# 148
# Sentiment(classification='pos', p_pos=0.5196648538932295, p_neg=0.48033514610677175)
# 149
# Sentiment(classification='neg', p_pos=0.3461944618518474, p_neg=0.6538055381481513)
# 150
# Sentiment(classification='pos', p_pos=0.5246609008148136, p_neg=0.47533909918518535)
# 151
# Sentiment(classification='neg', p_pos=0.13612512734077223, p_neg=0.8638748726592308)
# 152
# Sentiment(classification='neg', p_pos=0.4705157983905333, p_neg=0.5294842016094681)
# 153
# Sentiment(classification='neg', p_pos=0.4379727005827868, p_neg=0.5620272994172092)
# 154
# Sentiment(classification='pos', p_pos=0.9765004180707197, p_neg=0.023499581929277955)
# 155
# Sentiment(classification='pos', p_pos=0.5833488970967239, p_neg=0.4166511029032766)
# 156
# Sentiment(classification='pos', p_pos=0.9989726469835905, p_neg=0.0010273530164078845)
# 157
# Sentiment(classification='pos', p_pos=0.9619743676162305, p_neg=0.0380256323837673)
# 158
# Sentiment(classification='pos', p_pos=0.8674205167304458, p_neg=0.1325794832695553)
# 159
# Sentiment(classification='pos', p_pos=0.9440514161791781, p_neg=0.05594858382082552)
# 160
# Sentiment(classification='pos', p_pos=0.9323205418967542, p_neg=0.06767945810324426)
# 161
# Sentiment(classification='pos', p_pos=0.9915381945171994, p_neg=0.008461805482798911)
# 162
# Sentiment(classification='pos', p_pos=0.5201731877978274, p_neg=0.4798268122021739)
# 163
# Sentiment(classification='pos', p_pos=0.9677210313703699, p_neg=0.03227896862962853)
# 164
# Sentiment(classification='neg', p_pos=0.1628882598255505, p_neg=0.8371117401744503)
# 165
# Sentiment(classification='pos', p_pos=0.9407080368877614, p_neg=0.05929196311223443)
# 166
# Sentiment(classification='pos', p_pos=0.9622247631603636, p_neg=0.0377752368396363)
# 167
# Sentiment(classification='pos', p_pos=0.9027823333264812, p_neg=0.09721766667351708)
# 168
# Sentiment(classification='pos', p_pos=0.9307952785733782, p_neg=0.06920472142662479)
# 169
# Sentiment(classification='neg', p_pos=0.3891637932999453, p_neg=0.6108362067000511)
# 170
# Sentiment(classification='pos', p_pos=0.9042090222632507, p_neg=0.09579097773674836)
# 171
# Sentiment(classification='pos', p_pos=0.9828679119369486, p_neg=0.017132088063048365)
# 172
# Sentiment(classification='pos', p_pos=0.7767089290800392, p_neg=0.22329107091996223)
# 173
# Sentiment(classification='pos', p_pos=0.7966950953772575, p_neg=0.2033049046227427)
# 174
# Sentiment(classification='pos', p_pos=0.9999287366324108, p_neg=7.126336758657127e-05)
# 175
# Sentiment(classification='pos', p_pos=0.9568403048599909, p_neg=0.043159695140009044)
# 176
# Sentiment(classification='neg', p_pos=0.41351656973450945, p_neg=0.5864834302654887)
# 177
# Sentiment(classification='pos', p_pos=0.902365249916498, p_neg=0.097634750083502)
# 178
# Sentiment(classification='pos', p_pos=0.9587025433548906, p_neg=0.04129745664511028)
# 179
# Sentiment(classification='neg', p_pos=0.4302263651531541, p_neg=0.5697736348468442)
# 180
# Sentiment(classification='pos', p_pos=0.9483927868887664, p_neg=0.05160721311123159)
# 181
# Sentiment(classification='pos', p_pos=0.9970812207167526, p_neg=0.0029187792832493452)
# 182
# Sentiment(classification='pos', p_pos=0.8176116512704592, p_neg=0.1823883487295427)
# 183
# Sentiment(classification='pos', p_pos=0.8594372050364587, p_neg=0.14056279496353877)
# 184
# Sentiment(classification='pos', p_pos=0.9354862461142157, p_neg=0.0645137538857821)
# 185
# Sentiment(classification='pos', p_pos=0.9785891383195818, p_neg=0.021410861680418142)
# 186
# Sentiment(classification='pos', p_pos=0.8443709217439782, p_neg=0.15562907825602115)
# 187
# Sentiment(classification='pos', p_pos=0.9832128920118435, p_neg=0.016787107988155407)
# 188
# Sentiment(classification='pos', p_pos=0.8963310909408965, p_neg=0.10366890905910384)
# 189
# Sentiment(classification='neg', p_pos=0.36653829746115774, p_neg=0.6334617025388406)
# 190
# Sentiment(classification='neg', p_pos=0.3277315705418275, p_neg=0.6722684294581733)
# 191
# Sentiment(classification='neg', p_pos=0.16004370372719348, p_neg=0.8399562962728038)
# 192
# Sentiment(classification='pos', p_pos=0.8053652720372187, p_neg=0.1946347279627831)
# 193
# Sentiment(classification='pos', p_pos=0.8788232142738853, p_neg=0.12117678572611348)
# 194
# Sentiment(classification='pos', p_pos=0.9126646745514083, p_neg=0.08733532544859292)
# 195
# Sentiment(classification='pos', p_pos=0.5130939791636563, p_neg=0.4869060208363471)
# 196
# Sentiment(classification='neg', p_pos=0.09074376546553346, p_neg=0.9092562345344668)
# 197
# Sentiment(classification='pos', p_pos=0.9730539621122372, p_neg=0.026946037887764906)
# 198
# Sentiment(classification='pos', p_pos=0.9518369919318372, p_neg=0.048163008068165605)
# 199
# Sentiment(classification='pos', p_pos=0.9853687579719743, p_neg=0.014631242028027003)
# 200
# Sentiment(classification='pos', p_pos=0.8566824882225259, p_neg=0.14331751177747626)
# 201
# Sentiment(classification='pos', p_pos=0.5820649910648611, p_neg=0.41793500893513796)
# 202
# Sentiment(classification='pos', p_pos=0.5204898286767957, p_neg=0.4795101713232014)
# 203
# Sentiment(classification='pos', p_pos=0.9540066204645716, p_neg=0.045993379535431735)
# 204
# Sentiment(classification='pos', p_pos=0.5672198861031109, p_neg=0.4327801138968892)
# 205
# Sentiment(classification='pos', p_pos=0.5127648394173014, p_neg=0.4872351605826993)
# 206
# Sentiment(classification='pos', p_pos=0.7374426394944876, p_neg=0.26255736050550993)
# 207
# Sentiment(classification='neg', p_pos=0.25148292456574145, p_neg=0.7485170754342564)
# 208
# Sentiment(classification='neg', p_pos=0.22223233040719606, p_neg=0.777767669592806)
# 209
# Sentiment(classification='pos', p_pos=0.8518445519588922, p_neg=0.1481554480411068)
# 210
# Sentiment(classification='pos', p_pos=0.6184030277814012, p_neg=0.38159697221859784)
# 211
# Sentiment(classification='neg', p_pos=0.3160290067734464, p_neg=0.6839709932265551)
# 212
# Sentiment(classification='pos', p_pos=0.9597830254836014, p_neg=0.04021697451639733)
# 213
# Sentiment(classification='pos', p_pos=0.8567540988526966, p_neg=0.14324590114730432)
# 214
# Sentiment(classification='pos', p_pos=0.9974690114811571, p_neg=0.00253098851884699)
# 215
# Sentiment(classification='pos', p_pos=0.9339447938637384, p_neg=0.0660552061362604)
# 216
# Sentiment(classification='neg', p_pos=0.13965896280210052, p_neg=0.8603410371979)
# 217
# Sentiment(classification='pos', p_pos=0.5841815902209724, p_neg=0.41581840977903234)
# 218
# Sentiment(classification='neg', p_pos=0.307382621570029, p_neg=0.6926173784299694)
# 219
# Sentiment(classification='neg', p_pos=0.17187470236297803, p_neg=0.8281252976370206)
# 220
# Sentiment(classification='pos', p_pos=0.5611185026876413, p_neg=0.4388814973123594)
# 221
# Sentiment(classification='neg', p_pos=0.10166699659268168, p_neg=0.8983330034073214)
# 222
# Sentiment(classification='neg', p_pos=0.3696334284648465, p_neg=0.6303665715351521)
# 223
# Sentiment(classification='neg', p_pos=0.22900055056485566, p_neg=0.7709994494351462)
# 224
# Sentiment(classification='pos', p_pos=0.9967623380501871, p_neg=0.003237661949813251)
# 225
# Sentiment(classification='pos', p_pos=0.9843165001531458, p_neg=0.015683499846852546)
# 226
# Sentiment(classification='neg', p_pos=0.13045108136536743, p_neg=0.8695489186346311)
# 227
# Sentiment(classification='neg', p_pos=0.2900771760056035, p_neg=0.7099228239943991)
# 228
# Sentiment(classification='pos', p_pos=0.5175577096173711, p_neg=0.48244229038262754)
# 229
# Sentiment(classification='neg', p_pos=0.2154674549013848, p_neg=0.7845325450986151)
# 230
# Sentiment(classification='pos', p_pos=0.5548740496140976, p_neg=0.44512595038590236)
# 231
# Sentiment(classification='neg', p_pos=0.38076299870586533, p_neg=0.6192370012941337)
# 232
# Sentiment(classification='pos', p_pos=0.8806918257223916, p_neg=0.11930817427760694)
# 233
# Sentiment(classification='neg', p_pos=0.334388688600045, p_neg=0.6656113113999533)
# 234
# Sentiment(classification='neg', p_pos=0.20850008885741722, p_neg=0.7914999111425803)
# 235
# Sentiment(classification='pos', p_pos=0.8250846206161242, p_neg=0.17491537938387652)
# 236
# Sentiment(classification='pos', p_pos=0.7977597789232943, p_neg=0.2022402210767012)
# 237
# Sentiment(classification='pos', p_pos=0.9889323853620486, p_neg=0.011067614637954486)
# 238
# Sentiment(classification='pos', p_pos=0.8662069121418965, p_neg=0.13379308785810373)
# 239
# Overall positivity score:0.6195205506856273
# Overall negativity score:0.1885417402784815

# %%
reviews_boston.to_csv('Other Files\\sentiment.csv',encoding='UTF-8',index=False)

# %%
reviews1 = pd.read_csv('Other Files\\sentiment.csv')

# %%
import seaborn
reviews3=reviews1[['positivity','negativity']]
ax=reviews3.plot(kind='barh', stacked=True,title = "Positivity vs Negativity scores for reviews",legend=True)
ax.legend(bbox_to_anchor=(1.8, 0.5))
ax.set_xlabel("Score")
ax.set_ylabel("Index")
#for i, v in enumerate(reviews3['positivity']):
 #   ax.text(v + 3, i + .25, str(v), color='blue', fontweight='bold')

# %%
reviews.head()
# Out:
#    positivity  negativity
# 0   24.314830   75.685170
# 1   85.839924   14.160076
# 2   79.942673   20.057327
# 3   78.831975   21.168025
# 4   99.819236    0.180764

# %%
reviews1['Sentiment']= 0
reviews1['Sentiment'][reviews1['positivity'] > reviews1['negativity']]= 1
reviews1['Sentiment'][reviews1['negativity'] > reviews1['positivity']] = 0
# Out:
# C:\Users\Nimi\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# C:\Users\Nimi\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
reviews1.head(15)
# Out:
#     index                                     id  rating_x  \
# 0    4980                     75-chestnut-boston         5
# 1    4981                     75-chestnut-boston         4
# 2    4982                     75-chestnut-boston         2
# 3    4983             al-dente-restaurant-boston         5
# 4    4984             al-dente-restaurant-boston         5
# 5    4985             al-dente-restaurant-boston         5
# 6    4986           atlantic-fish-company-boston         5
# 7    4987           atlantic-fish-company-boston         4
# 8    4988           atlantic-fish-company-boston         3
# 9    4989                  audubon-boston-boston         5
# 10   4990                  audubon-boston-boston         4
# 11   4991                  audubon-boston-boston         3
# 12   4992  barcelona-wine-bar-south-end-boston-6         5
# 13   4993  barcelona-wine-bar-south-end-boston-6         4
# 14   4994  barcelona-wine-bar-south-end-boston-6         5
#
#            time_created                                               text  \
# 0   2017-04-10 07:38:14  This is an adorable spot on beacon hill quiet ...
# 1   2017-04-01 08:56:30  This is exactly what I needed my first night i...
# 2   2017-03-27 03:33:26  Came for Sunday Brunch. We were seated at a hi...
# 3   2017-04-13 08:56:17  While staying in Little Italy during a confere...
# 4   2017-04-01 12:52:14  I'll be honest I did not know what to expect w...
# 5   2017-03-18 08:49:46  Came here recently for a work lunch and I was ...
# 6   2017-04-09 17:12:59  Great times and great food. Made reservations ...
# 7   2017-03-25 07:56:20  Great ambience incredible food. I had the swor...
# 8   2017-03-23 21:22:51  Crab Louie:  The lobster and crab were definit...
# 9   2017-03-05 09:06:17  Could not have higher reviews for this place. ...
# 10  2017-03-25 06:49:54  After having Audubon bookmarked for months I f...
# 11  2017-02-01 06:47:08  I came here for brunch one day. I've walked by...
# 12  2017-04-13 09:15:12  One of my favorites. Experiences here are cons...
# 13  2017-04-03 22:32:33  Having been to Spain a couple times and dined ...
# 14  2017-04-02 17:00:52  Barcelona is my favorite restaurant in Boston ...
#
#       city  positivity  negativity  Sentiment
# 0   Boston   99.118558    0.881442          1
# 1   Boston   32.096252   67.903748          0
# 2   Boston   69.416336   30.583664          1
# 3   Boston   97.857127    2.142873          1
# 4   Boston   88.307355   11.692645          1
# 5   Boston   71.912894   28.087106          1
# 6   Boston   93.796855    6.203145          1
# 7   Boston   74.293736   25.706264          1
# 8   Boston   84.271685   15.728315          1
# 9   Boston   75.778882   24.221118          1
# 10  Boston   74.754443   25.245557          1
# 11  Boston   82.492953   17.507047          1
# 12  Boston   76.327007   23.672993          1
# 13  Boston   70.805103   29.194897          1
# 14  Boston   72.836779   27.163221          1

# %%
reviews2 = reviews1[0:1309].reset_index()

# %%
reviews2.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-7e014ceb0674> in <module>()
# ----> 1 reviews2.tail()
#
# NameError: name 'reviews2' is not defined

# %%
a= reviews2.groupby(['id','rating'], sort= True )

# %%
a.head()
# Out:
#                                            id  rating         time_created  \
# 0                             80-proof-sydney       4  2015-04-15 03:37:53
# 1                             80-proof-sydney       5  2016-04-13 02:45:30
# 2                             80-proof-sydney       4  2013-06-19 17:15:22
# 3                     alpha-restaurant-sydney       5  2016-07-08 19:34:56
# 4                     alpha-restaurant-sydney       4  2016-10-22 05:36:00
# 5                     alpha-restaurant-sydney       5  2015-09-13 18:28:05
# 6                                ambar-sydney       4  2016-04-14 16:25:38
# 7                                ambar-sydney       3  2014-08-06 17:07:38
# 8                                ambar-sydney       4  2015-07-07 02:03:02
# 9               aria-restaurant-sydney-sydney       5  2017-04-15 01:28:56
# 10              aria-restaurant-sydney-sydney       4  2017-04-09 15:02:32
# 11              aria-restaurant-sydney-sydney       5  2016-06-17 00:22:27
# 12    bambini-trust-cafe-and-wine-room-sydney       4  2016-10-22 14:54:20
# 13    bambini-trust-cafe-and-wine-room-sydney       4  2015-11-09 03:27:41
# 14    bambini-trust-cafe-and-wine-room-sydney       2  2015-07-14 01:51:59
# 15                    bang-street-food-sydney       4  2016-06-05 18:50:39
# 16                    bang-street-food-sydney       3  2016-02-13 14:07:08
# 17                    bang-street-food-sydney       3  2016-02-06 13:35:20
# 18                            bar-luca-sydney       4  2016-12-13 18:29:57
# 19                            bar-luca-sydney       3  2017-04-05 15:09:50
# 20                            bar-luca-sydney       4  2017-04-17 09:16:19
# 21                        bar-tapavino-sydney       5  2015-08-24 23:16:18
# 22                        bar-tapavino-sydney       4  2016-11-25 16:36:20
# 23                        bar-tapavino-sydney       3  2016-07-26 23:10:02
# 24                    barista-and-cook-sydney       4  2016-04-02 20:05:02
# 25                    barista-and-cook-sydney       3  2016-10-19 03:14:28
# 26                    barista-and-cook-sydney       2  2016-10-19 02:57:59
# 27                       barrio-cellar-sydney       4  2016-12-02 12:35:57
# 28                       barrio-cellar-sydney       4  2016-09-07 17:47:10
# 29                       barrio-cellar-sydney       4  2016-09-15 16:14:56
# ...                                       ...     ...                  ...
# 1279   cluny-bistro-and-boulangerie-toronto-2       5  2017-03-27 19:34:42
# 1280   cluny-bistro-and-boulangerie-toronto-2       1  2017-04-18 11:40:14
# 1281   cluny-bistro-and-boulangerie-toronto-2       3  2017-04-15 18:00:26
# 1282                 cocina-economica-toronto       5  2017-02-07 18:31:09
# 1283                 cocina-economica-toronto       1  2017-04-20 09:48:54
# 1284                 cocina-economica-toronto       4  2017-02-01 08:55:00
# 1285                         completo-toronto       5  2017-04-14 10:11:04
# 1286                         completo-toronto       5  2017-01-11 19:04:20
# 1287                         completo-toronto       5  2017-01-11 17:02:24
# 1288                          corks-toronto-2       5  2016-10-15 12:18:26
# 1289                          corks-toronto-2       3  2016-09-24 09:16:55
# 1290                          corks-toronto-2       4  2016-08-27 04:30:23
# 1291                         corrados-toronto       5  2017-01-04 12:32:51
# 1292                         corrados-toronto       4  2017-04-10 15:36:17
# 1293                         corrados-toronto       2  2017-03-12 16:11:36
# 1294         dominion-pub-and-kitchen-toronto       5  2017-01-22 09:30:27
# 1295         dominion-pub-and-kitchen-toronto       3  2017-01-13 20:34:54
# 1296         dominion-pub-and-kitchen-toronto       2  2016-11-02 22:52:09
# 1297        dumpling-house-restaurant-toronto       4  2017-04-12 20:12:50
# 1298        dumpling-house-restaurant-toronto       4  2017-03-25 11:57:35
# 1299        dumpling-house-restaurant-toronto       5  2017-03-10 11:05:55
# 1300                  east-thirty-six-toronto       4  2017-03-05 21:19:20
# 1301                  east-thirty-six-toronto       2  2017-02-15 04:58:28
# 1302                  east-thirty-six-toronto       3  2017-01-19 05:34:13
# 1303                  eastside-social-toronto       5  2017-01-09 19:21:33
# 1304                  eastside-social-toronto       4  2016-11-21 05:36:08
# 1305                  eastside-social-toronto       3  2017-03-27 17:49:43
# 1306           el-catrin-destileria-toronto-3       4  2017-04-18 14:00:45
# 1307           el-catrin-destileria-toronto-3       3  2017-03-31 19:34:32
# 1308           el-catrin-destileria-toronto-3       5  2017-03-13 15:17:54
#
#                                                    text  positivity  \
# 0     Right under my nose! like literally. My collea...   24.314830
# 1     Great food!  Good portions at a reasonable pri...   85.839924
# 2     Very chill and cozy place to hang out (Can't c...   79.942673
# 3     If you're into something fancy this place is y...   78.831975
# 4     well if u want to take someone special on date...   99.819236
# 5     Have been here a couple of times now and every...   93.403016
# 6     Almost didn't find this place got stuck in the...   98.383920
# 7     This is a great "catching up with old work col...   36.688401
# 8     Another good place for afterwork drinks. Their...   57.781524
# 9     Aria was everything my husband and I hoped for...   97.865310
# 10    Amazing customer service made a reservation a ...   99.220554
# 11    I won a $200 Good Food voucher at work and fig...   80.525380
# 12    Bambini is a cozy small restaurant with food a...   55.005398
# 13    Really nice place tO have breakfast meeting. O...   86.187549
# 14    I was here today on a business lunch seven of ...   95.034293
# 15    Delicious dinner!The food here tastes really u...   99.293081
# 16    Ok I don't know why this place advertises as B...   56.251417
# 17    I came here for a work dinner last week off th...   46.778855
# 18    Bar Luca should be on everyone's "must try" li...   33.454272
# 19    We ordered the all famous "Blame Canada Burger...   61.098079
# 20    We came here on our first night in Sydney. Lov...   27.277844
# 21    Upstairs is for bookings downstairs is for wal...   80.912496
# 22    We stopped by here before heading to the Opera...   62.356697
# 23    Situated close to Circular Quay and next to th...   68.045354
# 24    Creative menu and friendly team. Good new comm...   90.003126
# 25    Came here on invite from a friend to catch up....   37.327552
# 26    I have nothing against healthy eating but when...    5.164091
# 27    I set out on a weekday evening to meet some gi...   11.152691
# 28    Work knows I don't join them for lunch unless ...   33.320132
# 29    A friend recently took me here and I was very ...   95.981828
# ...                                                 ...         ...
# 1279  This place is absolutely beautiful. The decor ...   47.006937
# 1280  the bartender started w. a $20. glass pour of ...   52.540514
# 1281  First impressions may matter but there needs t...   77.384315
# 1282  This was the best Mexican food I have eaten. I...   17.930737
# 1283  Rebeca was serving us. We ordered 2 meals. My ...   69.096255
# 1284  One of the best Mexican restaurants in town! F...   79.849863
# 1285  If you want the most delicious sandwich in Tor...   75.705152
# 1286  Definitely my favourite tacos in Leslieville. ...   74.277223
# 1287  Holy crap their tacos are defreakinglicious! F...   85.090121
# 1288  Love this place I work nearby and we come here...   92.636087
# 1289  Thank goodness for reviews on yelp. This place...   79.708094
# 1290  It's everything the other reviewers say it is:...   53.238100
# 1291  Amazing veal parmigian sandwich and the lady w...   18.402954
# 1292  A walk from the CN Tower pleasant and the the ...   90.944747
# 1293  I ordered: Rice ball with meat sauce and chees...   96.949922
# 1294  Fantastic find on Queen East! I absolutely lov...   99.427764
# 1295  This place has a nice vibe and good service.  ...   88.592561
# 1296  Same owners and identical menu to the Pour Hou...   72.845804
# 1297  Fast and cheap place for dumplings. If you jus...   13.564688
# 1298  We almost left when we arrived at Dumpling Hou...   46.915351
# 1299  My favourite kind of house music is "Dumpling ...   35.264516
# 1300  Super conflicted review here..We got the sword...   92.412366
# 1301  Pro: Outstanding welcoming staff friendly pati...   99.802663
# 1302  Tried the fries with fried chicken skin but it...   45.242096
# 1303  The food is truly fantastic.  I came thinking ...   98.652549
# 1304  We were able to get a reservation for Saturday...   55.787874
# 1305  Over priced for the food. Oysters on special a...   26.167933
# 1306  I went to El Catrin with a few friends for a w...   67.059117
# 1307  Came for dinner around 8PM on this cold rainy ...   97.460387
# 1308  This has become one of my favourite Mexican re...   83.398647
#
#       negativity  Sentiment
# 0      75.685170          0
# 1      14.160076          1
# 2      20.057327          1
# 3      21.168025          1
# 4       0.180764          1
# 5       6.596984          1
# 6       1.616080          1
# 7      63.311599          0
# 8      42.218476          1
# 9       2.134690          1
# 10      0.779446          1
# 11     19.474620          1
# 12     44.994602          1
# 13     13.812451          1
# 14      4.965707          1
# 15      0.706919          1
# 16     43.748583          1
# 17     53.221145          0
# 18     66.545728          0
# 19     38.901921          1
# 20     72.722156          0
# 21     19.087504          1
# 22     37.643303          1
# 23     31.954646          1
# 24      9.996874          1
# 25     62.672448          0
# 26     94.835909          0
# 27     88.847309          0
# 28     66.679868          0
# 29      4.018172          1
# ...          ...        ...
# 1279   52.993063          0
# 1280   47.459486          1
# 1281   22.615685          1
# 1282   82.069263          0
# 1283   30.903745          1
# 1284   20.150137          1
# 1285   24.294848          1
# 1286   25.722777          1
# 1287   14.909879          1
# 1288    7.363913          1
# 1289   20.291906          1
# 1290   46.761900          1
# 1291   81.597046          0
# 1292    9.055253          1
# 1293    3.050078          1
# 1294    0.572236          1
# 1295   11.407439          1
# 1296   27.154196          1
# 1297   86.435312          0
# 1298   53.084649          0
# 1299   64.735484          0
# 1300    7.587634          1
# 1301    0.197337          1
# 1302   54.757904          0
# 1303    1.347451          1
# 1304   44.212126          1
# 1305   73.832067          0
# 1306   32.940883          1
# 1307    2.539613          1
# 1308   16.601353          1
#
# [1309 rows x 7 columns]

# %%
datafr=pd.read_csv(r"Other Files\YelpData.csv",encoding='utf-8')
countryliving='US'

# %%
datafr.head()
# Out:
#                                         id                            name  \
# 0                          80-proof-sydney                        80 Proof
# 1                  alpha-restaurant-sydney                Alpha Restaurant
# 2                             ambar-sydney                           Ambar
# 3            aria-restaurant-sydney-sydney          ARIA Restaurant Sydney
# 4  bambini-trust-cafe-and-wine-room-sydney  Bambini Trust Cafe & Wine Room
#
#    review_count price is_closed   latitude   longitude    city state zip_code  \
# 0             5   NaN     False -33.876675  151.206010  Sydney   NSW     2000
# 1            26   $$$     False -33.875243  151.209271  Sydney   NSW     2000
# 2             5     $     False -33.868154  151.209339  Sydney   NSW     2000
# 3            57  $$$$     False -33.859173  151.213177  Sydney   NSW     2000
# 4            13   $$$     False -33.872391  151.209625  Sydney   NSW     2000
#
#   country  rating         phone         term  \
# 0      AU     4.0  6.129263e+10  restaurants
# 1      AU     4.0  6.129098e+10  restaurants
# 2      AU     4.0  6.129223e+10  restaurants
# 3      AU     3.5  6.129252e+10  restaurants
# 4      AU     4.0  6.129284e+10  restaurants
#
#                                                image
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/l8YhtI...
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/amSYJH...
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/k5KyZo...
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/hxspCd...
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/31fB5o...

# %%
datafr1=datafr[['id','city','state','country','latitude','longitude']]

# %%
datafr1.head()
# Out:
#                                         id    city state country   latitude  \
# 0                          80-proof-sydney  Sydney   NSW      AU -33.876675
# 1                  alpha-restaurant-sydney  Sydney   NSW      AU -33.875243
# 2                             ambar-sydney  Sydney   NSW      AU -33.868154
# 3            aria-restaurant-sydney-sydney  Sydney   NSW      AU -33.859173
# 4  bambini-trust-cafe-and-wine-room-sydney  Sydney   NSW      AU -33.872391
#
#     longitude
# 0  151.206010
# 1  151.209271
# 2  151.209339
# 3  151.213177
# 4  151.209625

# %%
new_review = pd.merge(datafr1, reviews2,  how='inner', left_on=['id'], right_on = ['id'])

# %%
new_review.head()
# Out:
#                         id    city state country   latitude   longitude  \
# 0          80-proof-sydney  Sydney   NSW      AU -33.876675  151.206010
# 1          80-proof-sydney  Sydney   NSW      AU -33.876675  151.206010
# 2          80-proof-sydney  Sydney   NSW      AU -33.876675  151.206010
# 3  alpha-restaurant-sydney  Sydney   NSW      AU -33.875243  151.209271
# 4  alpha-restaurant-sydney  Sydney   NSW      AU -33.875243  151.209271
#
#    rating         time_created  \
# 0       4  2015-04-15 03:37:53
# 1       5  2016-04-13 02:45:30
# 2       4  2013-06-19 17:15:22
# 3       5  2016-07-08 19:34:56
# 4       4  2016-10-22 05:36:00
#
#                                                 text  positivity  negativity  \
# 0  Right under my nose! like literally. My collea...   24.314830   75.685170
# 1  Great food!  Good portions at a reasonable pri...   85.839924   14.160076
# 2  Very chill and cozy place to hang out (Can't c...   79.942673   20.057327
# 3  If you're into something fancy this place is y...   78.831975   21.168025
# 4  well if u want to take someone special on date...   99.819236    0.180764
#
#    Sentiment
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1

# %%
new_review_NSW=new_review[new_review['state']=='NSW']
new_review_NSW['longitude'].max()
# Out:
# 151.256134

# %%
-33.906 -33.835
151.185  151.256

# %%
import matplotlib
import matplotlib.pyplot as plt
#print(cuisine4)
# %matplotlib inline
import seaborn as sns
#ax=sns.factorplot("title", "count",
#                               data=cuisine4, kind="bar",orient="h",
#                               size=10, palette="muted", legend=False)
#plt.savefig(r'Output Files\Analysis 1\Plot\Restaurant-Per-Capita.jpg')
ax = sns.barplot(x="Sentiment", y="rating", orient= "v", data=reviews2)
#print('CSV Files and Plots saved successfully')
ax.set(xlabel='Sentiment', ylabel='rating')
plt.title("Rating Vs Sentiment ",fontsize=15)
#for index, row in cuisine4.iterrows():
 #   ax.text(row.count,row.count, row.count, color='black', ha="center")
plt.show()

# %%
-33.906 -33.835
151.185  151.256

# %%
fig = plt.figure(figsize=(5,5))
plt.scatter(new_review_NSW['longitude'], new_review_NSW['latitude'], color='blue', s=5, label='Positive')
plt.scatter(new_review_NSW['longitude'], new_review_NSW['latitude'], color='red', s=2, label='Negative')
plt.title('Sentiment Analysis Distribution', fontsize='30')
plt.xlabel('Longitude', fontsize='18')
plt.ylabel('Latitude', fontsize='18')
plt.xlim(151.185,151.23)    #-74.259090,-73.700272)
plt.ylim(-33.906, -33.835)     #40.477399, 40.917577)
#plt.grid()
plt.gca().set_axis_bgcolor('white')
plt.legend()
plt.show()
# Out:
# C:\Users\Nimi\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: MatplotlibDeprecationWarning: The set_axis_bgcolor function was deprecated in version 2.0. Use set_facecolor instead.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import gmplot

from mpl_toolkits.basemap import Basemap

# %%
datafr1=data[['id','city','state','country','latitude','longitude']]

# %%
reviews12 = pd.merge(reviews1, datafr1,  how='left', left_on=['id'], right_on = ['id'])

# %%
reviews12.head()
# Out:
#    index                          id  rating_x         time_created  \
# 0   4980          75-chestnut-boston         5  2017-04-10 07:38:14
# 1   4981          75-chestnut-boston         4  2017-04-01 08:56:30
# 2   4982          75-chestnut-boston         2  2017-03-27 03:33:26
# 3   4983  al-dente-restaurant-boston         5  2017-04-13 08:56:17
# 4   4984  al-dente-restaurant-boston         5  2017-04-01 12:52:14
#
#                                                 text  city_x  positivity  \
# 0  This is an adorable spot on beacon hill quiet ...  Boston   99.118558
# 1  This is exactly what I needed my first night i...  Boston   32.096252
# 2  Came for Sunday Brunch. We were seated at a hi...  Boston   69.416336
# 3  While staying in Little Italy during a confere...  Boston   97.857127
# 4  I'll be honest I did not know what to expect w...  Boston   88.307355
#
#    negativity  Sentiment  city_y state country   latitude  longitude
# 0    0.881442          1  Boston    MA      US  42.356934 -71.070984
# 1   67.903748          0  Boston    MA      US  42.356934 -71.070984
# 2   30.583664          1  Boston    MA      US  42.356934 -71.070984
# 3    2.142873          1  Boston    MA      US  42.364220 -71.055360
# 4   11.692645          1  Boston    MA      US  42.364220 -71.055360

# %%
df=pd.DataFrame()
df['latitude']=reviews12['latitude'].ffill()
df['longitude']=reviews12['longitude'].ffill()
latitudes=df['latitude']
longitudes=df['longitude']
latitudes=latitudes.tolist()
longitudes=longitudes.tolist()

# %%
reviews12_latitude = reviews12.latitude
reviews12_longitude = reviews12.longitude

reviews12_lat = reviews12_latitude.tolist()
reviews12_lng = reviews12_longitude.toli

# %%
gmap = gmplot.GoogleMapPlotter(reviews12_lat[0], reviews12_lng[0], 14)

gmap.scatter(reviews12_lat, reviews12_lng, '#3F3067', size=20, marker=False)
#gmap.scatter(hotels_lat, hotels_lng, '#BB1F5C', size=20, marker=False)

gmap.draw(r'mymap.html')

# %%
-33.906 -33.835
151.185  151.256

# %%
figComp= plt.figure(figsize=(20,20))


themap = Basemap(projection='mill', llcrnrlat=42.23, urcrnrlat=42.40, llcrnrlon=-71.18, urcrnrlon=-70.99, epsg=4269)

themap.drawcountries()
themap.drawstates()
themap.drawrivers()
themap.drawmapboundary()
themap.arcgisimage(service='NatGeo_World_Map')
ncolors = 20

cmap = plt.get_cmap('coolwarm')

x,y = themap(reviews12.longitude.values, reviews12.latitude.values)
themap.scatter(x,y, color = '#3F3067', alpha=0.8, label = 'Restaurants')

#x1,y1 = themap(hotel_longitude, hotel_latitude)
#themap.scatter(x1,y1, color = 'red', alpha=0.8, label='Hotels')

legend = plt.legend(frameon = True, fontsize=26, loc='upper left', markerscale=4)
frame = legend.get_frame()
frame.set_color('white')
plt.show()

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# %%
# let's first define a helper function to plot the map of Bay Area in US. 

def plot_map(service = 'ESRI_Imagery_World_2D', epsg = 4269, xpixels = 5000):
    # note, you need change the epsg for different region, 
    #US is 4269, and you can google the region you want
    plt.figure(figsize = (8, 8))
    #m = Basemap(projection='mill',llcrnrlon=-123. ,llcrnrlat=37,
      #  urcrnrlon=-121 ,urcrnrlat=39, resolution = 'l', epsg = epsg)
    m=Basemap(projection='mill', llcrnrlon=-71.1334228515625, llcrnrlat=42.322506782299797, urcrnrlon=-71.035987943405004, urcrnrlat=42.376663461327603, resolution='l',epsg=epsg)
    x,y = themap(reviews12.longitude.values, reviews12.latitude.values)
    m.scatter(x,y, color = '#3F3067', alpha=0.8, label = 'Restaurants')
    
    # xpixels controls the pixels in x direction, and if you leave ypixels
    # None, it will choose ypixels based on the aspect ratio
    m.arcgisimage(service=service, xpixels = xpixels, verbose= False)
    
    plt.show()

# %%
plot_map(service = 'ESRI_Imagery_World_2D', epsg = 4269)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-106-614015dab75f> in <module>()
# ----> 1 plot_map(service = 'NatGeo_World_Map', epsg = 4269)
#
# <ipython-input-105-b31af82be29e> in plot_map(service, epsg, xpixels)
#      13     # xpixels controls the pixels in x direction, and if you leave ypixels
#      14     # None, it will choose ypixels based on the aspect ratio
# ---> 15     m.arcgisimage(service=service, xpixels = xpixels, verbose= False)
#      16
#      17     plt.show()
#
# C:\Users\Nimi\Anaconda3\lib\site-packages\mpl_toolkits\basemap\__init__.py in arcgisimage(self, server, service, xpixels, ypixels, dpi, verbose, **kwargs)
#    4249         if verbose: print(basemap_url)
#    4250         # return AxesImage instance.
# -> 4251         return self.imshow(imread(urllib.request.urlopen(basemap_url)),ax=ax,
#    4252                            origin='upper')
#    4253
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
#     468         # post-process response
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     482         protocol = req.type
#     483         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 484                                   '_open', req)
#     485         if result:
#     486             return result
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     442         for handler in handlers:
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#     446                 return result
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in http_open(self, req)
#    1280
#    1281     def http_open(self, req):
# -> 1282         return self.do_open(http.client.HTTPConnection, req)
#    1283
#    1284     http_request = AbstractHTTPHandler.do_request_
#
# C:\Users\Nimi\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1255             except OSError as err: # timeout error
#    1256                 raise URLError(err)
# -> 1257             r = h.getresponse()
#    1258         except:
#    1259             h.close()
#
# C:\Users\Nimi\Anaconda3\lib\http\client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# C:\Users\Nimi\Anaconda3\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\Nimi\Anaconda3\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\Nimi\Anaconda3\lib\socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
reviews12['latitude'].max()
# Out:
# 42.376663461327603

# %%
reviews12['latitude'].min()
# Out:
# 42.322506782299797

# %%
reviews12['longitude'].min()
# Out:
# -71.1334228515625

# %%
reviews12['longitude'].max()
# Out:
# -71.035987943405004
